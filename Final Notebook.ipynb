# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Mariam</b>
# <br></br>Student

# %% [markdown]
# _I'm interested in data science because I want a career shift._

# %% [markdown]
# <h3> It will print Hello World </h3>

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# <ol>
#     <li>English</li>
#     <li>Mathematics</li>
#     <li>Science</li>
# </ol>
# <hr></hr>Horizontal Rule<hr></hr>
# <ul>
#     <li>Whatsapp</li>
#     <li>Snapchat</li>
#     <li>Twitter</li>
# </ul>

# %% [markdown]
# ![properties-of-rectangle-01-1642149798.png](attachment:properties-of-rectangle-01-1642149798.png)
# <strike> This is going to be awkward</strike><br></br>
# <a href="https://www.google.com/">Visit Google.com!</a><br></br>
# <mark>Let's highlight something!</mark><br></br>
# <blockquote>Block Quote is here to stay</blockquote>
